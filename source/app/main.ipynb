# %%
# !python3 app.py
# Out:
# Using cuda device
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5001
#  * Running on http://172.19.0.2:5001
# Press CTRL+C to quit
# 172.19.0.1 - - [14/Jul/2026 09:42:07] "GET / HTTP/1.1" 200 -
# 172.19.0.1 - - [14/Jul/2026 09:42:07] "GET / HTTP/1.1" 200 -
# 172.19.0.1 - - [14/Jul/2026 09:42:07] "GET /static/style.css HTTP/1.1" 200 -
# 172.19.0.1 - - [14/Jul/2026 09:42:07] "GET /favicon.ico HTTP/1.1" 404 -
# 172.19.0.1 - - [14/Jul/2026 09:43:19] "POST / HTTP/1.1" 200 -
# 172.19.0.1 - - [14/Jul/2026 09:43:19] "GET / HTTP/1.1" 200 -
# 172.19.0.1 - - [14/Jul/2026 09:43:19] "GET /static/style.css HTTP/1.1" 304 -
# 172.19.0.1 - - [14/Jul/2026 09:43:19] "GET /uploads/output15_0-00-01-16.jpg HTTP/1.1" 200 -
